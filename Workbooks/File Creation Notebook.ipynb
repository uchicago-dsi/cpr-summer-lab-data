# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import json
import matplotlib.pyplot as plt
import fiona
import pyproj
import contextily
import plotly.express as px
from shapely import wkt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
path = "/srv/data/my_shared_data_folder/cpr/"

dir_list = os.listdir(path)
#dir_in = os.listdir(os.getcwd())
#directory = pd.Series(dir_in)
#print(dir_in)
print(dir_list)
# Out:
# ['california_counties_census_data.csv', 'cleaned_county_data.csv', 'R13391251_SL140.csv', 'R13391250_SL050.csv', 'california_tracts.gpkg', 'pur2020_nonag.parquet', 'cleaned_tract_data.csv', 'cleaned_elsd_data.csv', 'california_zctas.gpkg', 'california_counties.gpkg', 'vision_providers_geocoded.csv', 'california_watersheds.gpkg', 'california_zcta_census_data.csv', 'R13391252_SL950.csv', 'new_test_file.gpkg', 'readme.md', 'california_elementary_school_districts.gpkg', 'pur2020_ag.parquet', 'california_tracts_census_data.csv', 'cleaned_zcta_data.csv', 'california_elementary_schools_census_data.csv', 'R13391293_SL860.csv', 'another_copy_pur2020_ag.parquet']

# %% [markdown]
# # READ
# This notebook consolidates all code used to create the files used for visualization and analysis. Any checkpoint is an optional place where you can choose to save a file, but is not a final file that ended up being used for analysis. This is a consolidation: the file are to be created one at a time, which will be indicated with each new file name, as well as the code to load in prior created files. The files documented in this notebook are as follows:
# 1. county_w_geo.geojson
# 2. tract_w_geo.geojson
# 3. tracts_w_geo+.geojson
# 4. demographic_merge.geojson
# 5. Pesticide_5.csv
# 6. pesticide_5_meridian.csv
# 7. Pesticide_5_w_tracts.csv
# 8. Pesticide_5_w_tracts+.csv
# 9. places_w_MTownshipRange
#
# ## We typically default to using the crs 4326 for compatibility with plotly choropleths
# - - -

# %% [markdown]
# # 1. county_w_geo.geojson
# uses files:
# 1. california_counties.gpkg
# 2. cleaned_county_data.csv

# %%
# loading in county geometry
geometry = gpd.read_file(path + '/california_counties.gpkg', engine = 'fiona')

# %%
# rename for clarity
geometry.rename(columns = {'GEOID': 'StateCountyFIPS'},inplace = True)

# %%
# loading in county data
data = pd.read_csv(path + '/cleaned_county_data.csv')

# %%
# functions for cleaning "data"
# these help reformat the numeric data as strings, which is useful in the case of FIPS codes
# please look up FIPS codes to understand their makeup for this merge
def fix_StCounty(string):
    if (len(string) == 4):
        fix = '0' + string
    elif (len(string) == 5):
        fix = string
    else: return np.nan
    
    return fix

def fix_St(string):
    if (len(string) == 1):
        fix = '0' + string
    elif (len(string) == 2):
        fix = string
    else: return np.nan
    
    return fix

def fix_Cnty(string):
    if (len(string) == 1):
        fix = '00' + string
    elif (len(string) == 2):
        fix = '0' + string
    elif (len(string) == 3):
        fix = string
    else: return np.nan
    
    return fix

# %%
# reformatting as FP strings
# two daisy chained operations: turning numeric to string and applying string cleaning functions
data['FIPS'] = data['FIPS'].apply(lambda x: str(x)).apply(fix_StCounty)
data['state_fips'] = data['state_fips'].apply(lambda x: str(x)).apply(fix_St)
data['county'] = data['county'].apply(lambda x: str(x)).apply(fix_Cnty)

# fixing names to improve labeling
data.rename(columns = {'FIPS': 'StateCountyFIPS','state_fips': 'STATEFP','county': 'COUNTYFP'}, inplace = True)

# %%
# dropping empty tract column 
data.drop(columns = ['tract'], inplace = True)

# %%
merge = geometry.merge(data, on=['StateCountyFIPS','STATEFP','COUNTYFP'])

# %%
# adding geometry type for later filtering
merge['geometry_type'] = 'county'

# %%
# adding explicit county name for later filtering
merge['county_name'] = merge['NAME']

# %%
# changing crs for later plotting
merge.to_crs(pyproj.CRS.from_epsg(4326), inplace = True)

# %%
merge.head(2)
# Out:
#   STATEFP COUNTYFP  COUNTYNS StateCountyFIPS        NAME           NAMELSAD  \
# 0      06      091  00277310           06091      Sierra      Sierra County
# 1      06      067  00277298           06067  Sacramento  Sacramento County
#
#   LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# 0   06      H1  G4020   NaN    NaN      NaN        A  2468694587  23299110
# 1   06      H1  G4020   472  40900      NaN        A  2499183617  76073827
#
#       INTPTLAT      INTPTLON  \
# 0  +39.5769252  -120.5219926
# 1  +38.4500114  -121.3404409
#
#                                             geometry state         geoid  \
# 0  MULTIPOLYGON (((-120.65560 39.69357, -120.6555...    ca  05000US06091
# 1  MULTIPOLYGON (((-121.18858 38.71431, -121.1873...    ca  05000US06067
#
#            area_name   area_land  total_pop  housing_units  \
# 0      Sierra County  953.168327       3079           2099
# 1  Sacramento County  965.273130    1571767         583858
#
#    owner_occupied_housing_units  persons_no_health_insurance  families  \
# 0                           908                          474       728
# 1                        323018                        84824    370480
#
#    families_income_below_poverty_level  median_household_income  \
# 0                                   23                    56152
# 1                                35387                    76422
#
#    nh_white_alone  nh_black_or_african_american_alone  \
# 0            2692                                   2
# 1          674153                              145916
#
#    nh_american_indian_and_alaska_native_alone  nh_asian_alone  \
# 0                                          28               0
# 1                                        4057          261202
#
#    nh_native_hawaiian_and_other_pacific_islander_alone  nh_other  \
# 0                                                  0           0
# 1                                              17387        5925
#
#    nh_two_or_more  hispanic_or_latino  households_receiving_assistance  \
# 0              12                 345                              475
# 1           88395              374732                           371775
#
#    households  pct_owner_occupied  pct_no_health_insurance  \
# 0        1151            0.432587                 0.153946
# 1      559036            0.553248                 0.053967
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.031593
# 1                                 0.095517
#
#    pct_households_receiving_assistance  pct_nh_white_alone  \
# 0                             0.412685            0.874310
# 1                             0.665029            0.428914
#
#    pct_nh_black_or_african_american_alone  \
# 0                                0.000650
# 1                                0.092836
#
#    pct_nh_american_indian_and_alaska_native_alone  pct_nh_asian_alone  \
# 0                                        0.009094            0.000000
# 1                                        0.002581            0.166184
#
#    pct_nh_native_hawaiian_and_other_pacific_islander_alone  pct_nh_other  \
# 0                                           0.000000             0.00000
# 1                                           0.011062             0.00377
#
#    pct_nh_two_or_more  pct_hispanic_or_latino geometry_type county_name
# 0            0.003897                0.112049        county      Sierra
# 1            0.056239                0.238414        county  Sacramento

# %%
merge.to_file('county_w_geo.geojson',driver = 'GeoJSON', crs = merge.crs)

# %%
# test = gpd.read_file('./Files/county_w_geo.geojson')
# test

# %% [markdown]
# - - -
# - - -

# %% [markdown]
# # 2 - 3. tract_w_geo.geojson & tract_w_geo+.geojson
# uses files:
# 1. tl_2021_06_tract.shp
# 2. cleaned_tract_data.csv

# %%
# loading in tract geometry
# note that you need all files in the shape folder for this to work properly
geometry = gpd.read_file("../../data/tract_shape/tl_2021_06_tract.shp")

# %%
# renaming for consistency
geometry.rename(columns = {'TRACTCE':'TRACTFP'},inplace = True)
geometry.rename(columns = {'GEOID':'FIPS GEOID'},inplace = True)

# %%
geometry.head(2)
# Out:
#   STATEFP COUNTYFP TRACTFP   FIPS GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      085  504321  06085504321  5043.21  Census Tract 5043.21  G5020
# 1      06      085  504410  06085504410  5044.10  Census Tract 5044.10  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  1450237       0  +37.3931319  -121.8651427
# 1        S  1102136       0  +37.4093719  -121.8788884
#
#                                             geometry
# 0  POLYGON ((-121.87556 37.39924, -121.87535 37.3...
# 1  POLYGON ((-121.88886 37.40758, -121.88576 37.4...

# %%
# loading in tract data
data = pd.read_csv(path + 'cleaned_tract_data.csv')

# %%
# defining functions for cleaning string
# please refer to FIPS makeup
def FIPS_cleaner(string):
    if len(string) == 10:
        fix = '0' + string
    elif len(string) == 11:
        fix = string
    else: return np.nan
    
    return fix

def fix_St(string):
    if (len(string) == 1):
        fix = '0' + string
    elif (len(string) == 2):
        fix = string
    else: return np.nan
    
    return fix

def fix_Cnty(string):
    if (len(string) == 1):
        fix = '00' + string
    elif (len(string) == 2):
        fix = '0' + string
    elif (len(string) == 3):
        fix = string
    else: return np.nan
    
    return fix

# %%
# converting to strings for FIPS merge consistency
data['FIPS'] = data['FIPS'].apply(lambda x: str(x)).apply(FIPS_cleaner)
data['state_fips'] = data['state_fips'].apply(lambda x: str(x)).apply(fix_St)
data['county'] = data['county'].apply(lambda x: str(x)).apply(fix_Cnty)
# fixing names
data.rename(columns = {'state_fips': 'STATEFP','county': 'COUNTYFP'}, inplace = True)

# %%
# converting population to numeric
data['total_pop'] = data["total_pop"].apply(lambda x: int(x))

# %%
# merging to append geometry
merge = geometry.merge(data, left_on = ['FIPS GEOID','STATEFP','COUNTYFP'], right_on = ['FIPS','STATEFP','COUNTYFP'], how="left")

# %%
# returning FIPS to numeric
merge['FIPS GEOID'] = merge['FIPS GEOID'].apply(lambda x: int(x))

# %%
# standardizing crs
merge.to_crs(pyproj.CRS.from_epsg(4326), inplace = True)

# %%
merge.head(2)
# Out:
#   STATEFP COUNTYFP TRACTFP  FIPS GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      085  504321  6085504321  5043.21  Census Tract 5043.21  G5020
# 1      06      085  504410  6085504410  5044.10  Census Tract 5044.10  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  1450237       0  +37.3931319  -121.8651427
# 1        S  1102136       0  +37.4093719  -121.8788884
#
#                                             geometry         FIPS state  \
# 0  POLYGON ((-121.87556 37.39924, -121.87535 37.3...  06085504321    ca
# 1  POLYGON ((-121.88886 37.40758, -121.88576 37.4...  06085504410    ca
#
#     tract               geoid             area_name  area_land  total_pop  \
# 0  504321  14000US06085504321  Census Tract 5043.21   0.559940       5511
# 1  504410  14000US06085504410  Census Tract 5044.10   0.425537       4286
#
#    housing_units  owner_occupied_housing_units  persons_no_health_insurance  \
# 0           1779                          1131                          212
# 1           1244                           688                          189
#
#    families  families_income_below_poverty_level  median_household_income  \
# 0      1316                                   60                 146941.0
# 1       934                                  102                 128523.0
#
#    nh_white_alone  nh_black_or_african_american_alone  \
# 0             544                                  77
# 1             556                                 165
#
#    nh_american_indian_and_alaska_native_alone  nh_asian_alone  \
# 0                                           0            3559
# 1                                          77            2476
#
#    nh_native_hawaiian_and_other_pacific_islander_alone  nh_other  \
# 0                                                  0           7
# 1                                                  0           0
#
#    nh_two_or_more  hispanic_or_latino  households_receiving_assistance  \
# 0             269                1055                              962
# 1              94                 918                              589
#
#    households  pct_owner_occupied  pct_no_health_insurance  \
# 0        1675            0.635750                 0.038469
# 1        1214            0.553055                 0.044097
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.045593
# 1                                 0.109208
#
#    pct_households_receiving_assistance  pct_nh_white_alone  \
# 0                             0.574328            0.098712
# 1                             0.485173            0.129725
#
#    pct_nh_black_or_african_american_alone  \
# 0                                0.013972
# 1                                0.038497
#
#    pct_nh_american_indian_and_alaska_native_alone  pct_nh_asian_alone  \
# 0                                        0.000000            0.645799
# 1                                        0.017965            0.577695
#
#    pct_nh_native_hawaiian_and_other_pacific_islander_alone  pct_nh_other  \
# 0                                                0.0             0.00127
# 1                                                0.0             0.00000
#
#    pct_nh_two_or_more  pct_hispanic_or_latino
# 0            0.048811                0.191435
# 1            0.021932                0.214186

# %% [markdown]
# - - -
# ## Checkpoint: 2. tract_w_geo.geojson

# %%
merge.to_file('tract_w_geo.geojson',driver = 'GeoJSON', crs = merge.crs)

# %%
merge = gpd.read_file('./Files/tract_w_geo.geojson')

# %%
merge.head(2)
# Out:
#   STATEFP COUNTYFP TRACTFP  FIPS GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      085  504321  6085504321  5043.21  Census Tract 5043.21  G5020
# 1      06      085  504410  6085504410  5044.10  Census Tract 5044.10  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON         FIPS state  \
# 0        S  1450237       0  +37.3931319  -121.8651427  06085504321    ca
# 1        S  1102136       0  +37.4093719  -121.8788884  06085504410    ca
#
#     tract               geoid             area_name  area_land  total_pop  \
# 0  504321  14000US06085504321  Census Tract 5043.21   0.559940       5511
# 1  504410  14000US06085504410  Census Tract 5044.10   0.425537       4286
#
#    housing_units  owner_occupied_housing_units  persons_no_health_insurance  \
# 0           1779                          1131                          212
# 1           1244                           688                          189
#
#    families  families_income_below_poverty_level  median_household_income  \
# 0      1316                                   60                 146941.0
# 1       934                                  102                 128523.0
#
#    nh_white_alone  nh_black_or_african_american_alone  \
# 0             544                                  77
# 1             556                                 165
#
#    nh_american_indian_and_alaska_native_alone  nh_asian_alone  \
# 0                                           0            3559
# 1                                          77            2476
#
#    nh_native_hawaiian_and_other_pacific_islander_alone  nh_other  \
# 0                                                  0           7
# 1                                                  0           0
#
#    nh_two_or_more  hispanic_or_latino  households_receiving_assistance  \
# 0             269                1055                              962
# 1              94                 918                              589
#
#    households  pct_owner_occupied  pct_no_health_insurance  \
# 0        1675            0.635750                 0.038469
# 1        1214            0.553055                 0.044097
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.045593
# 1                                 0.109208
#
#    pct_households_receiving_assistance  pct_nh_white_alone  \
# 0                             0.574328            0.098712
# 1                             0.485173            0.129725
#
#    pct_nh_black_or_african_american_alone  \
# 0                                0.013972
# 1                                0.038497
#
#    pct_nh_american_indian_and_alaska_native_alone  pct_nh_asian_alone  \
# 0                                        0.000000            0.645799
# 1                                        0.017965            0.577695
#
#    pct_nh_native_hawaiian_and_other_pacific_islander_alone  pct_nh_other  \
# 0                                                0.0             0.00127
# 1                                                0.0             0.00000
#
#    pct_nh_two_or_more  pct_hispanic_or_latino  \
# 0            0.048811                0.191435
# 1            0.021932                0.214186
#
#                                             geometry
# 0  POLYGON ((-121.87556 37.39924, -121.87535 37.3...
# 1  POLYGON ((-121.88886 37.40758, -121.88576 37.4...

# %% [markdown]
# - - -

# %% [markdown]
# # 3. tracts_w_geo+.geojson
# tract_w_geo.geojson, with additions:
# 1. column for county name
#
# needed files:
# 1. tract_w_geo.geojson
# 2. county_w_geo.geojson

# %%
# reading in counties
counties = gpd.read_file('./Files/county_w_geo.geojson')

# %%
# merging to append county name to tract data, based on county FIPS code
tracts = merge.merge(counties[['COUNTYFP','county_name']], on = 'COUNTYFP', how = 'left')

# %%
tracts.head(2)
# Out:
#   STATEFP COUNTYFP TRACTFP  FIPS GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      085  504321  6085504321  5043.21  Census Tract 5043.21  G5020
# 1      06      085  504410  6085504410  5044.10  Census Tract 5044.10  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON         FIPS state  \
# 0        S  1450237       0  +37.3931319  -121.8651427  06085504321    ca
# 1        S  1102136       0  +37.4093719  -121.8788884  06085504410    ca
#
#     tract               geoid             area_name  area_land  total_pop  \
# 0  504321  14000US06085504321  Census Tract 5043.21   0.559940       5511
# 1  504410  14000US06085504410  Census Tract 5044.10   0.425537       4286
#
#    housing_units  owner_occupied_housing_units  persons_no_health_insurance  \
# 0           1779                          1131                          212
# 1           1244                           688                          189
#
#    families  families_income_below_poverty_level  median_household_income  \
# 0      1316                                   60                 146941.0
# 1       934                                  102                 128523.0
#
#    nh_white_alone  nh_black_or_african_american_alone  \
# 0             544                                  77
# 1             556                                 165
#
#    nh_american_indian_and_alaska_native_alone  nh_asian_alone  \
# 0                                           0            3559
# 1                                          77            2476
#
#    nh_native_hawaiian_and_other_pacific_islander_alone  nh_other  \
# 0                                                  0           7
# 1                                                  0           0
#
#    nh_two_or_more  hispanic_or_latino  households_receiving_assistance  \
# 0             269                1055                              962
# 1              94                 918                              589
#
#    households  pct_owner_occupied  pct_no_health_insurance  \
# 0        1675            0.635750                 0.038469
# 1        1214            0.553055                 0.044097
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.045593
# 1                                 0.109208
#
#    pct_households_receiving_assistance  pct_nh_white_alone  \
# 0                             0.574328            0.098712
# 1                             0.485173            0.129725
#
#    pct_nh_black_or_african_american_alone  \
# 0                                0.013972
# 1                                0.038497
#
#    pct_nh_american_indian_and_alaska_native_alone  pct_nh_asian_alone  \
# 0                                        0.000000            0.645799
# 1                                        0.017965            0.577695
#
#    pct_nh_native_hawaiian_and_other_pacific_islander_alone  pct_nh_other  \
# 0                                                0.0             0.00127
# 1                                                0.0             0.00000
#
#    pct_nh_two_or_more  pct_hispanic_or_latino  \
# 0            0.048811                0.191435
# 1            0.021932                0.214186
#
#                                             geometry  county_name
# 0  POLYGON ((-121.87556 37.39924, -121.87535 37.3...  Santa Clara
# 1  POLYGON ((-121.88886 37.40758, -121.88576 37.4...  Santa Clara

# %%
tracts.to_file('tracts_w_geo+.geojson',driver = 'GeoJSON', crs = tracts.crs)

# %%
test = gpd.read_file('./Files/tracts_w_geo+.geojson')
test

# %% [markdown]
# - - -
# - - -

# %% [markdown]
# # 4. demographic_merge.geojson
# needed files
# 1. tract_w_geo+.geojson
# 2. county_w_geo.geojson

# %%
# read in county data
counties = gpd.read_file('./Files/county_w_geo.geojson')

# %%
# read in tract data
tracts = gpd.read_file('./Files/tracts_w_geo+.geojson')

# %%
# concatenating dataframe
merge = pd.concat([tracts,counties])

# %%
merge.head(2)
# Out:
#   STATEFP COUNTYFP TRACTFP    FIPS GEOID     NAME              NAMELSAD  \
# 0      06      085  504321  6.085504e+09  5043.21  Census Tract 5043.21
# 1      06      085  504410  6.085504e+09  5044.10  Census Tract 5044.10
#
#    MTFCC FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON         FIPS  \
# 0  G5020        S  1450237       0  +37.3931319  -121.8651427  06085504321
# 1  G5020        S  1102136       0  +37.4093719  -121.8788884  06085504410
#
#   state     tract               geoid             area_name  area_land  \
# 0    ca  504321.0  14000US06085504321  Census Tract 5043.21   0.559940
# 1    ca  504410.0  14000US06085504410  Census Tract 5044.10   0.425537
#
#    total_pop  housing_units  owner_occupied_housing_units  \
# 0       5511           1779                          1131
# 1       4286           1244                           688
#
#    persons_no_health_insurance  families  families_income_below_poverty_level  \
# 0                          212      1316                                   60
# 1                          189       934                                  102
#
#    median_household_income  nh_white_alone  \
# 0                 146941.0             544
# 1                 128523.0             556
#
#    nh_black_or_african_american_alone  \
# 0                                  77
# 1                                 165
#
#    nh_american_indian_and_alaska_native_alone  nh_asian_alone  \
# 0                                           0            3559
# 1                                          77            2476
#
#    nh_native_hawaiian_and_other_pacific_islander_alone  nh_other  \
# 0                                                  0           7
# 1                                                  0           0
#
#    nh_two_or_more  hispanic_or_latino  households_receiving_assistance  \
# 0             269                1055                              962
# 1              94                 918                              589
#
#    households  pct_owner_occupied  pct_no_health_insurance  \
# 0        1675            0.635750                 0.038469
# 1        1214            0.553055                 0.044097
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.045593
# 1                                 0.109208
#
#    pct_households_receiving_assistance  pct_nh_white_alone  \
# 0                             0.574328            0.098712
# 1                             0.485173            0.129725
#
#    pct_nh_black_or_african_american_alone  \
# 0                                0.013972
# 1                                0.038497
#
#    pct_nh_american_indian_and_alaska_native_alone  pct_nh_asian_alone  \
# 0                                        0.000000            0.645799
# 1                                        0.017965            0.577695
#
#    pct_nh_native_hawaiian_and_other_pacific_islander_alone  pct_nh_other  \
# 0                                                0.0             0.00127
# 1                                                0.0             0.00000
#
#    pct_nh_two_or_more  pct_hispanic_or_latino  county_name  \
# 0            0.048811                0.191435  Santa Clara
# 1            0.021932                0.214186  Santa Clara
#
#                                             geometry COUNTYNS StateCountyFIPS  \
# 0  POLYGON ((-121.87556 37.39924, -121.87535 37.3...      NaN             NaN
# 1  POLYGON ((-121.88886 37.40758, -121.88576 37.4...      NaN             NaN
#
#   LSAD CLASSFP CSAFP CBSAFP METDIVFP geometry_type
# 0  NaN     NaN   NaN    NaN      NaN           NaN
# 1  NaN     NaN   NaN    NaN      NaN           NaN

# %%
merge.to_file('demographic_merge.geojson',driver = 'GeoJSON', crs = merge.crs)

# %%
# test = gpd.read_file('./Files/demographic_merge.geojson')
# test

# %% [markdown]
# - - -
# - - -

# %% [markdown]
# # 5-8. Pesticide_5.csv, pesticide_5_meridian.csv,
# # Pesticide_5_w_tracts.csv,Pesticide_5_w_tracts+.csv
# files needed:
# 1. pur2018_withtypes.csv
# 2. pur2019_withtypes.csv
# 3. pur2020_withtypes.csv
# 4. pur2021_withtypes.csv

# %%
# read in first two years of pesticide data, this already has been fuzzy matched for pesticide type
pd2018 = pd.read_csv("../../data/basefile/pur2018_withtypes.csv",low_memory = False,index_col=0)
pd2019 = pd.read_csv("../../data/basefile/pur2019_withtypes.csv",low_memory = False,index_col=0)

# %%
# read in next two years
pd2020 = pd.read_csv("../../data/basefile/pur2020_withtypes.csv",low_memory = False,index_col=0)
pd2021 = pd.read_csv("../../data/basefile/pur2021_withtypes.csv",low_memory = False,index_col=0)

# %%
# concatenating dataframes
Pesticide_5 = pd.concat([pd2018,pd2019,pd2020,pd2021])

# %%
Pesticide_5.head(2)
# Out:
#   ADJUVANT  YEAR       DATE COUNTY_NAME       COMTRS  \
# 0       NO  2018  09-FEB-18      FRESNO  10M11S13E15
# 1      NaN  2018  06-SEP-18      FRESNO  10M13S13E17
#
#                                  SITE_NAME          PRODUCT_NAME  \
# 0  ALFALFA (FORAGE - FODDER) (ALFALFA HAY)  2,4-DB 200 HERBICIDE
# 1  ALFALFA (FORAGE - FODDER) (ALFALFA HAY)                 8-8-2
#
#    POUNDS_PRODUCT_APPLIED                   CHEMICAL_NAME  \
# 0                486.7475  4-(2,4-DB), DIMETHYLAMINE SALT
# 1                 19.8856                             NaN
#
#    POUNDS_CHEMICAL_APPLIED  AMOUNT_TREATED UNIT_TREATED  \
# 0               127.527845            69.8            A
# 1                      NaN            75.0            A
#
#   AERIAL_GROUND_INDICATOR Meridian  County_Code Township Range  Section  \
# 0                       G      MDM           10     T11S  R13E     15.0
# 1                       A      MDM           10     T13S  R13E     17.0
#
#                           pur2020             chem_type      ratio   air  \
# 0  4-(2,4-DB), DIMETHYLAMINE SALT  D DIMETHYLAMINE SALT  97.560976  True
# 1                             NaN                   NaN        NaN   NaN
#
#    chem_code                   chemname carcinogens endo_disrupt   ch_I  \
# 0      806.0  2,4-D, DIMETHYLAMINE SALT       False        False  False
# 1        NaN                        NaN         NaN          NaN    NaN
#
#   fumigants neonicotinoids repro_dev
# 0     False          False     False
# 1       NaN            NaN       NaN

# %% [markdown]
# - - -
# ## Checkpoint: 5. Pesticide_5.csv

# %%
Pesticide_5.to_csv('Pesticide_5.csv')

# %%
Pesticide_5 = pd.read_csv('./Files/Pesticide_5.csv', low_memory = False, index_col = 0)

# %% [markdown]
# - - -

# %% [markdown]
# # 6. Pesticide_5_Meridian.csv
# Pesticide_5, with additions:
# 1. added meridian
# 2. dropped any non-ag pesticides
# 3. focuses on subset of currently used columns
#
# files needed
# 1. Pesticide_5.csv

# %%
# dropping incomplete comtrs: length should == 11 for agriculture
data = Pesticide_5.loc[Pesticide_5['COMTRS'].apply(len) == 11]

# %%
# creates TownshipRange column, look up PLSS township range system
data['TownshipRange'] = data['Township'] + " " + data['Range']
# Out:
# /tmp/ipykernel_2668372/750142773.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['TownshipRange'] = data['Township'] + " " + data['Range']

# %%
# taking character that is representative of meridian, we believe that our original files had incorrect meridian
data['Meridian'] = data['COMTRS'].str[2]
# relabeling to the full meridian name
data['Meridian'] = data['Meridian'].replace({'S':'SBM','M':'MDM','H':'HM'})
# Out:
# /tmp/ipykernel_2668372/512622698.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Meridian'] = data['COMTRS'].str[2]
# /tmp/ipykernel_2668372/512622698.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Meridian'] = data['Meridian'].replace({'S':'SBM','M':'MDM','H':'HM'})

# %%
# dropping unneeded columns
data.drop(columns = ['DATE','SITE_NAME','PRODUCT_NAME','CHEMICAL_NAME','POUNDS_CHEMICAL_APPLIED','UNIT_TREATED','Township','Range','pur2020','chem_type','ratio','chem_code','chemname'], inplace = True)
# Out:
# /tmp/ipykernel_2668372/476140911.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns = ['DATE','SITE_NAME','PRODUCT_NAME','CHEMICAL_NAME','POUNDS_CHEMICAL_APPLIED','UNIT_TREATED','Township','Range','pur2020','chem_type','ratio','chem_code','chemname'], inplace = True)

# %%
# reseting the index
data.reset_index(inplace = True)
data.drop(columns = ['index'],inplace = True)
# Out:
# /tmp/ipykernel_2668372/3895165254.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns = ['index'],inplace = True)

# %%
# code for converting county code to county fips
# THESE ARE NOT THE SAME THING
def Ccode_to_Cfp(num):
    Cfp = num * 2 - 1
    Cfp = str(Cfp)
    if (len(Cfp) == 1):
        fix = '00' + Cfp
    elif (len(Cfp) == 2):
        fix = '0' + Cfp
    elif (len(Cfp) == 3):
        fix = Cfp
    else: return np.nan

    return fix

# code to convert county fips to cleaned county fips string
def Cfp_to_CfpString(num):
    Cfp = str(num)
    if (len(Cfp) == 1):
        fix = '00' + Cfp
    elif (len(Cfp) == 2):
        fix = '0' + Cfp
    elif (len(Cfp) == 3):
        fix = Cfp
    else: return np.nan

    return fix

# %%
# creates county FIPS column
data['COUNTYFP'] = data.County_Code.apply(Ccode_to_Cfp)
# Out:
# /tmp/ipykernel_2668372/3664731223.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['COUNTYFP'] = data.County_Code.apply(Ccode_to_Cfp)

# %%
# converting section to an integer
data['Section'] = data['Section'].apply(lambda x: int(x))
# Out:
# /tmp/ipykernel_2668372/3415772470.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Section'] = data['Section'].apply(lambda x: int(x))

# %%
data
# Out:
#         ADJUVANT  YEAR COUNTY_NAME       COMTRS  POUNDS_PRODUCT_APPLIED  \
# 0             NO  2018      FRESNO  10M11S13E15                486.7475
# 1            NaN  2018      FRESNO  10M13S13E17                 19.8856
# 2            NaN  2018      FRESNO  10M12S13E14                 15.3373
# 3             NO  2018      FRESNO  10M15S16E18                 74.9825
# 4             NO  2018      FRESNO  10M15S16E35                129.3698
# ...          ...   ...         ...          ...                     ...
# 4856494      NaN  2021    MONTEREY  27M14S02E24                  4.1428
# 4856495       NO  2021    MONTEREY  27M20S08E05                 82.6086
# 4856496      NaN  2021    MONTEREY  27M16S05E21                  8.6431
# 4856497       NO  2021    MONTEREY  27M20S08E05                  1.5837
# 4856498       NO  2021    MONTEREY  27M16S05E21                  0.6530
#
#          AMOUNT_TREATED AERIAL_GROUND_INDICATOR Meridian  County_Code  \
# 0                  69.8                       G      MDM           10
# 1                  75.0                       A      MDM           10
# 2                  57.9                       A      MDM           10
# 3                  40.0                       G      MDM           10
# 4                  69.0                       G      MDM           10
# ...                 ...                     ...      ...          ...
# 4856494             8.9                       G      MDM           27
# 4856495            45.0                       G      MDM           27
# 4856496             9.5                       G      MDM           27
# 4856497            45.0                       G      MDM           27
# 4856498             9.5                       G      MDM           27
#
#          Section   air carcinogens endo_disrupt   ch_I fumigants  \
# 0             15  True       False        False  False     False
# 1             17   NaN         NaN          NaN    NaN       NaN
# 2             14   NaN         NaN          NaN    NaN       NaN
# 3             18   NaN         NaN          NaN    NaN       NaN
# 4             35   NaN         NaN          NaN    NaN       NaN
# ...          ...   ...         ...          ...    ...       ...
# 4856494       24   NaN         NaN          NaN    NaN       NaN
# 4856495        5   NaN         NaN          NaN    NaN       NaN
# 4856496       21   NaN         NaN          NaN    NaN       NaN
# 4856497        5   NaN         NaN          NaN    NaN       NaN
# 4856498       21   NaN         NaN          NaN    NaN       NaN
#
#         neonicotinoids repro_dev TownshipRange COUNTYFP
# 0                False     False     T11S R13E      019
# 1                  NaN       NaN     T13S R13E      019
# 2                  NaN       NaN     T12S R13E      019
# 3                  NaN       NaN     T15S R16E      019
# 4                  NaN       NaN     T15S R16E      019
# ...                ...       ...           ...      ...
# 4856494            NaN       NaN     T14S R02E      053
# 4856495            NaN       NaN     T20S R08E      053
# 4856496            NaN       NaN     T16S R05E      053
# 4856497            NaN       NaN     T20S R08E      053
# 4856498            NaN       NaN     T16S R05E      053
#
# [4856499 rows x 19 columns]

# %% [markdown]
# - - -
# ## Checkpoint: 6. pesticide_5_meridian.csv

# %%
data.to_csv('pesticide_5_Meridian.csv')

# %%
data = pd.read_csv('./Files/pesticide_5_Meridian.csv',index_col = 0)

# %%
data.head(2)
# Out:
#   ADJUVANT  YEAR COUNTY_NAME       COMTRS  POUNDS_PRODUCT_APPLIED  \
# 0       NO  2018      FRESNO  10M11S13E15                486.7475
# 1      NaN  2018      FRESNO  10M13S13E17                 19.8856
#
#    AMOUNT_TREATED AERIAL_GROUND_INDICATOR Meridian  County_Code  Section  \
# 0            69.8                       G      MDM           10       15
# 1            75.0                       A      MDM           10       17
#
#     air carcinogens endo_disrupt   ch_I fumigants neonicotinoids repro_dev  \
# 0  True       False        False  False     False          False     False
# 1   NaN         NaN          NaN    NaN       NaN            NaN       NaN
#
#   TownshipRange  COUNTYFP
# 0     T11S R13E        19
# 1     T13S R13E        19

# %% [markdown]
# - - -

# %% [markdown]
# # 7. Pesticide_5_w_tracts.csv
# Same as pesticide_5_meridian, with additions
# 1. added tract information relating to where pesticide is used
#
# files needed
# 1. pesticide_5_Meridian.csv
# 2. mapper_sections_tracts_5_newtracts.csv

# %%
# read in mapper to get tracts for pesticide use
mapper = pd.read_csv('../../data/mapper_sections_tracts_5_newtracts.csv',index_col = 0)

# %%
# function used for cleaning townshiprange for creating COMTRS
# puts it into the same townshiprange format for COMTRS
def reduce(TownshipRange):
    fix = TownshipRange[1:]
    fix = fix.replace(' R','')
    return fix

# code to convert county fips to cleaned county fips string
def Cfp_to_CfpString(num):
    Cfp = str(num)
    if (len(Cfp) == 1):
        fix = '00' + Cfp
    elif (len(Cfp) == 2):
        fix = '0' + Cfp
    elif (len(Cfp) == 3):
        fix = Cfp
    else: return np.nan

    return fix

# %%
# turning county FIPS to string to use for COMTRS creation
mapper['COUNTYFP'] = mapper['COUNTYFP'].apply(Cfp_to_CfpString)

# %%
# creating COMTRS, this will be used to merge
mapper['COMTRS'] = (mapper['COUNTY_CODE'].apply(int)).apply(str) + mapper['Meridian'].str[0] + mapper['TownshipRange'].apply(reduce) + mapper['Section'].apply(lambda x: (str(x)).zfill(2))

# %%
# COMTRS captures all information from these columns, we drop them now
# geometry is not tract geometry, justifying drop
mapper.drop(columns = ['COUNTY_CODE','Meridian','Section', 'geometry','COUNTYFP','MTRS'], inplace = True)

# %%
# converting county code to county fips
data['COUNTYFP'] = data.County_Code.apply(Ccode_to_Cfp)

# %%
# return sections to integer
data['Section'] = data['Section'].apply(lambda x: int(x))

# %%
data.head(2)
# Out:
#   ADJUVANT  YEAR COUNTY_NAME       COMTRS  POUNDS_PRODUCT_APPLIED  \
# 0       NO  2018      FRESNO  10M11S13E15                486.7475
# 1      NaN  2018      FRESNO  10M13S13E17                 19.8856
#
#    AMOUNT_TREATED AERIAL_GROUND_INDICATOR Meridian  County_Code  Section  \
# 0            69.8                       G      MDM           10       15
# 1            75.0                       A      MDM           10       17
#
#     air carcinogens endo_disrupt   ch_I fumigants neonicotinoids repro_dev  \
# 0  True       False        False  False     False          False     False
# 1   NaN         NaN          NaN    NaN       NaN            NaN       NaN
#
#   TownshipRange COUNTYFP
# 0     T11S R13E      019
# 1     T13S R13E      019

# %%
final_cut = pd.merge(data, mapper, left_on = ['COMTRS','TownshipRange'], right_on = ['COMTRS','TownshipRange'], how = 'inner')

# %%
# dropping columns with missing tract information
final_cut = final_cut.loc[final_cut['TRACTCE'].isna() == False]

# %%
final_cut.head(2)
# Out:
#   ADJUVANT  YEAR COUNTY_NAME       COMTRS  POUNDS_PRODUCT_APPLIED  \
# 0       NO  2018      FRESNO  10M11S13E15                486.7475
# 1       NO  2018      FRESNO  10M11S13E15                 69.1503
#
#    AMOUNT_TREATED AERIAL_GROUND_INDICATOR Meridian  County_Code  Section  \
# 0            69.8                       G      MDM           10       15
# 1            69.8                       G      MDM           10       15
#
#     air carcinogens endo_disrupt   ch_I fumigants neonicotinoids repro_dev  \
# 0  True       False        False  False     False          False     False
# 1   NaN         NaN          NaN    NaN       NaN            NaN       NaN
#
#   TownshipRange  COUNTYFP  TRACTCE
# 0     T11S R13E        19     8402
# 1     T11S R13E        19     8402

# %% [markdown]
# - - -
# # Checkpoint: 7. Pesticide_5_w_tracts.csv

# %%
final_cut.to_csv('pesticide_5_w_tracts.csv')

# %%
final_cut = pd.read_csv('./Files/pesticide_5_w_tracts.csv', index_col = 0)

# %%
final_cut.head(2)
# Out:
#   ADJUVANT  YEAR COUNTY_NAME       COMTRS  POUNDS_PRODUCT_APPLIED  \
# 0       NO  2018      FRESNO  10M11S13E15                486.7475
# 1       NO  2018      FRESNO  10M11S13E15                 69.1503
#
#    AMOUNT_TREATED AERIAL_GROUND_INDICATOR Meridian  County_Code  Section  \
# 0            69.8                       G      MDM           10       15
# 1            69.8                       G      MDM           10       15
#
#     air carcinogens endo_disrupt   ch_I fumigants neonicotinoids repro_dev  \
# 0  True       False        False  False     False          False     False
# 1   NaN         NaN          NaN    NaN       NaN            NaN       NaN
#
#   TownshipRange  COUNTYFP  TRACTCE
# 0     T11S R13E        19     8402
# 1     T11S R13E        19     8402

# %% [markdown]
# - - -
# - - -

# %% [markdown]
# # 8. pesticide_5_w_tracts+.csv
# similiar to pesticide_5_w_Meridian, with additions:
# 1. makes FIPS code for tract pesticide was used in
# 2. makes a column that consolidates meridian and townshiprange
#
# files needed:
# 1. pesticide_5_Meridian.csv
# 2. mapper_sections_tracts_5_newtracts.csv
#
# The plus version of this file has very few differences, once difference is that we retain more columns and perform the merge using more columns, but also require less preprocessing of the mapping file, we foregoe making the COMTRS which summarizes many other columns. We also add a column that consolidates meridian and townshiprange, for plotting later

# %%
# reading in pesticide data
data = pd.read_csv('./Files/pesticide_5_Meridian.csv',index_col = 0)

# %%
# dropping columns we will not use in this case
data.drop(columns = ['COMTRS','AERIAL_GROUND_INDICATOR','County_Code',],inplace = True)

# %%
# read in mapper to get tracts for pesticide use
mapper = pd.read_csv('../../data/mapper_sections_tracts_5_newtracts.csv',index_col = 0)

# %%
# dropping geometry, not tract geometry
mapper.drop(columns = ['geometry'], inplace = True)

# %%
# merging to gain tract information
final_cut = pd.merge(data, mapper, on = ['COUNTYFP','Meridian','TownshipRange','Section'], how = 'left')

# %%
# drop any columns missing tract information
final_cut = final_cut.loc[final_cut['TRACTCE'].isna() == False]

# %%
# convering county FIPS code to string
def Cfp_to_CfpString(num):
    Cfp = str(num)
    if (len(Cfp) == 1):
        fix = '00' + Cfp
    elif (len(Cfp) == 2):
        fix = '0' + Cfp
    elif (len(Cfp) == 3):
        fix = Cfp
    else: return np.nan

    return fix

# converts tract into FIPS format
def tract_fixer(num):
    num = str(num)
    if (len(num) >= 2) & (len(num) <=6):
        zero_times = 6 - len(num)
        fix = zero_times*'0' + num
        return fix
    else: return np.nan

# %%
# convert tractce to integer values
final_cut['TRACTCE'] = final_cut['TRACTCE'].astype(int)

# convert county fips code to string
final_cut['COUNTYFP'] = final_cut['COUNTYFP'].apply(Cfp_to_CfpString)

# convert tract to tract string in FIPS format
final_cut['TRACTFP'] = final_cut['TRACTCE'].apply(tract_fixer)

# creating FIPS for where pesticide was applied
final_cut['PU_FIPS'] = '06' + final_cut['COUNTYFP'] + final_cut['TRACTFP']

# creates identifier that uses both township and meridian, for plotting uniqueness
# note that tractce, tract number is not unique for the state level, it should be unique up to the meridian however
# COMTRS should be even more 1-1, or PU_FIPS
final_cut['MTownshipRange'] = final_cut.Meridian + final_cut.TownshipRange

# creates generic count column, used for groupby counting
final_cut['Count'] = 1

# returning FIPS to integer form
final_cut['PU_FIPS'] = final_cut['PU_FIPS'].apply(int)

# %%
# dropping column that are summarized in other columns
final_cut.drop(columns = ['Meridian','Section','TownshipRange','COUNTYFP','TRACTCE','MTRS','TRACTFP'],inplace = True)

# %%
# resetting index
final_cut.reset_index(inplace = True)
final_cut.drop(columns = 'index', inplace = True)

# %%
final_cut
# Out:
#         ADJUVANT  YEAR COUNTY_NAME  POUNDS_PRODUCT_APPLIED  AMOUNT_TREATED  \
# 0             NO  2018      FRESNO                486.7475            69.8
# 1            NaN  2018      FRESNO                 19.8856            75.0
# 2            NaN  2018      FRESNO                 15.3373            57.9
# 3             NO  2018      FRESNO                 74.9825            40.0
# 4             NO  2018      FRESNO                129.3698            69.0
# ...          ...   ...         ...                     ...             ...
# 4842576      NaN  2021    MONTEREY                  4.1428             8.9
# 4842577       NO  2021    MONTEREY                 82.6086            45.0
# 4842578      NaN  2021    MONTEREY                  8.6431             9.5
# 4842579       NO  2021    MONTEREY                  1.5837            45.0
# 4842580       NO  2021    MONTEREY                  0.6530             9.5
#
#         Meridian  Section   air carcinogens endo_disrupt   ch_I fumigants  \
# 0            MDM       15  True       False        False  False     False
# 1            MDM       17   NaN         NaN          NaN    NaN       NaN
# 2            MDM       14   NaN         NaN          NaN    NaN       NaN
# 3            MDM       18   NaN         NaN          NaN    NaN       NaN
# 4            MDM       35   NaN         NaN          NaN    NaN       NaN
# ...          ...      ...   ...         ...          ...    ...       ...
# 4842576      MDM       24   NaN         NaN          NaN    NaN       NaN
# 4842577      MDM        5   NaN         NaN          NaN    NaN       NaN
# 4842578      MDM       21   NaN         NaN          NaN    NaN       NaN
# 4842579      MDM        5   NaN         NaN          NaN    NaN       NaN
# 4842580      MDM       21   NaN         NaN          NaN    NaN       NaN
#
#         neonicotinoids repro_dev TownshipRange COUNTYFP  TRACTCE  \
# 0                False     False     T11S R13E      019     8402
# 1                  NaN       NaN     T13S R13E      019     8402
# 2                  NaN       NaN     T12S R13E      019     8405
# 3                  NaN       NaN     T15S R16E      019     8200
# 4                  NaN       NaN     T15S R16E      019     8200
# ...                ...       ...           ...      ...      ...
# 4842576            NaN       NaN     T14S R02E      053    10504
# 4842577            NaN       NaN     T20S R08E      053    11305
# 4842578            NaN       NaN     T16S R05E      053    14800
# 4842579            NaN       NaN     T20S R08E      053    11305
# 4842580            NaN       NaN     T16S R05E      053    14800
#
#                      MTRS  COUNTY_CODE TRACTFP     PU_FIPS MTownshipRange  \
# 0        MDM-T11S-R13E-15         10.0  008402  6019008402   MDMT11S R13E
# 1        MDM-T13S-R13E-17         10.0  008402  6019008402   MDMT13S R13E
# 2        MDM-T12S-R13E-14         10.0  008405  6019008405   MDMT12S R13E
# 3        MDM-T15S-R16E-18         10.0  008200  6019008200   MDMT15S R16E
# 4        MDM-T15S-R16E-35         10.0  008200  6019008200   MDMT15S R16E
# ...                   ...          ...     ...         ...            ...
# 4842576  MDM-T14S-R02E-24         27.0  010504  6053010504   MDMT14S R02E
# 4842577   MDM-T20S-R08E-5         27.0  011305  6053011305   MDMT20S R08E
# 4842578  MDM-T16S-R05E-21         27.0  014800  6053014800   MDMT16S R05E
# 4842579   MDM-T20S-R08E-5         27.0  011305  6053011305   MDMT20S R08E
# 4842580  MDM-T16S-R05E-21         27.0  014800  6053014800   MDMT16S R05E
#
#          Count
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 4842576      1
# 4842577      1
# 4842578      1
# 4842579      1
# 4842580      1
#
# [4842581 rows x 23 columns]

# %%
final_cut.to_csv('pesticide_5_w_tracts+.csv')

# %%
test = pd.read_csv('./Files/pesticide_5_w_tracts+.csv')

# %%
test
# Out:
#          Unnamed: 0 ADJUVANT  YEAR COUNTY_NAME  POUNDS_PRODUCT_APPLIED  \
# 0                 0       NO  2018      FRESNO                486.7475
# 1                 1      NaN  2018      FRESNO                 19.8856
# 2                 2      NaN  2018      FRESNO                 15.3373
# 3                 3       NO  2018      FRESNO                 74.9825
# 4                 4       NO  2018      FRESNO                129.3698
# ...             ...      ...   ...         ...                     ...
# 4842576     4842576      NaN  2021    MONTEREY                  4.1428
# 4842577     4842577       NO  2021    MONTEREY                 82.6086
# 4842578     4842578      NaN  2021    MONTEREY                  8.6431
# 4842579     4842579       NO  2021    MONTEREY                  1.5837
# 4842580     4842580       NO  2021    MONTEREY                  0.6530
#
#          AMOUNT_TREATED   air carcinogens endo_disrupt   ch_I fumigants  \
# 0                  69.8  True       False        False  False     False
# 1                  75.0   NaN         NaN          NaN    NaN       NaN
# 2                  57.9   NaN         NaN          NaN    NaN       NaN
# 3                  40.0   NaN         NaN          NaN    NaN       NaN
# 4                  69.0   NaN         NaN          NaN    NaN       NaN
# ...                 ...   ...         ...          ...    ...       ...
# 4842576             8.9   NaN         NaN          NaN    NaN       NaN
# 4842577            45.0   NaN         NaN          NaN    NaN       NaN
# 4842578             9.5   NaN         NaN          NaN    NaN       NaN
# 4842579            45.0   NaN         NaN          NaN    NaN       NaN
# 4842580             9.5   NaN         NaN          NaN    NaN       NaN
#
#         neonicotinoids repro_dev  COUNTY_CODE     PU_FIPS MTownshipRange  \
# 0                False     False         10.0  6019008402   MDMT11S R13E
# 1                  NaN       NaN         10.0  6019008402   MDMT13S R13E
# 2                  NaN       NaN         10.0  6019008405   MDMT12S R13E
# 3                  NaN       NaN         10.0  6019008200   MDMT15S R16E
# 4                  NaN       NaN         10.0  6019008200   MDMT15S R16E
# ...                ...       ...          ...         ...            ...
# 4842576            NaN       NaN         27.0  6053010504   MDMT14S R02E
# 4842577            NaN       NaN         27.0  6053011305   MDMT20S R08E
# 4842578            NaN       NaN         27.0  6053014800   MDMT16S R05E
# 4842579            NaN       NaN         27.0  6053011305   MDMT20S R08E
# 4842580            NaN       NaN         27.0  6053014800   MDMT16S R05E
#
#          Count
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 4842576      1
# 4842577      1
# 4842578      1
# 4842579      1
# 4842580      1
#
# [4842581 rows x 17 columns]

# %% [markdown]
# - - -
# - - -

# %% [markdown]
# # 9. places_w_MTownship.geojson
# same as Public_Land_Survey_System_(PLSS)%3A_Township_and_Range.geojson, with additions:
# 1. added columns MTownshipRange, for 1-1 plotting
# files needed
# 1. Public_Land_Survey_System_(PLSS)%3A_Township_and_Range.geojson

# %% [markdown]
# # NOTE:
# The code commented out below is a means to open the file as a geojson object, useful for choropleth plotting with featureidkey parameter of choropleth maps

# %%
# g = open('./places_w_MTownship.geojson')
# places2 = json.load(g)

# %%
# reading in geometry information for township ranges
places = gpd.read_file('../../data/Public_Land_Survey_System_(PLSS)%3A_Township_and_Range.geojson')

# %%
# this appends the township range with meridian information
places['MTownshipRange'] = places['Meridian'] + places['TownshipRange']

# %%
places.to_file('places_w_MTownship.geojson', driver = 'GeoJSON', crs = places.crs)
