# %%
#importing libraries...
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
#loading census data...
#tract = pd.read_csv('../cpr-summer-lab-data/data/cleaned_tract_data.csv')

# %%
import os

path2 = "/srv/data/my_shared_data_folder/cpr/"
dir_list2 = os.listdir(path2)
print(dir_list2)
# Out:
# ['california_counties_census_data.csv', 'cleaned_county_data.csv', 'R13391251_SL140.csv', 'R13391250_SL050.csv', 'california_tracts.gpkg', 'pur2020_nonag.parquet', 'cleaned_tract_data.csv', 'cleaned_elsd_data.csv', 'california_zctas.gpkg', 'california_counties.gpkg', 'vision_providers_geocoded.csv', 'california_watersheds.gpkg', 'california_zcta_census_data.csv', 'R13391252_SL950.csv', 'new_test_file.gpkg', 'readme.md', 'california_elementary_school_districts.gpkg', 'pur2020_ag.parquet', 'california_tracts_census_data.csv', 'cleaned_zcta_data.csv', 'california_elementary_schools_census_data.csv', 'R13391293_SL860.csv', 'another_copy_pur2020_ag.parquet']

# %%
california_tracts_census = gpd.read_file(path2 + 'california_tracts_census_data.csv')
california_tracts_census.head(5)

# %%
california_tracts_census = gpd.read_file(path2 + 'california_tracts_census_data.csv')
california_tracts_census.head(5)
# Out:
#           FIPS                                Qualifying Name  \
# 0     Geo_FIPS                                      Geo_QName
# 1  06001400100  Census Tract 4001, Alameda County, California
# 2  06001400200  Census Tract 4002, Alameda County, California
# 3  06001400300  Census Tract 4003, Alameda County, California
# 4  06001400400  Census Tract 4004, Alameda County, California
#
#   File identification State Postal Abbreviation Summary Level  \
# 0          Geo_FILEID                Geo_STUSAB    Geo_SUMLEV
# 1               ACSSF                        ca           140
# 2               ACSSF                        ca           140
# 3               ACSSF                        ca           140
# 4               ACSSF                        ca           140
#
#   Geographic Component Logical Record Number      US Census Region  \
# 0          Geo_GEOCOMP          Geo_LOGRECNO  Geo_US    Geo_REGION
# 1                   00               0002818
# ...

# %%
cleaned_tract = gpd.read_file(path2 + 'cleaned_tract_data.csv')
cleaned_tract.head(5)
# Out:
#           FIPS state state_fips county   tract               geoid  \
# 0  06001400100    ca         06    001  400100  14000US06001400100
# 1  06001400200    ca         06    001  400200  14000US06001400200
# 2  06001400300    ca         06    001  400300  14000US06001400300
# 3  06001400400    ca         06    001  400400  14000US06001400400
# 4  06001400500    ca         06    001  400500  14000US06001400500
#
#            area_name          area_land total_pop housing_units  ...  \
# 0  Census Tract 4001    2.6818101087727      3324          1478  ...
# 1  Census Tract 4002  0.226472091762587      2038           908  ...
# 2  Census Tract 4003  0.428897740066749      5449          2779  ...
# 3  Census Tract 4004  0.276502439393542      4384          1986  ...
# 4  Census Tract 4005  0.228350092741742      4048          1791  ...
#
#   pct_households_receiving_assistance   pct_nh_white_alone  \
# 0                  0.5228122662677637   0.7018652226233454
# ...

# %%
counties_census_data = gpd.read_file(path2 + 'california_counties_census_data.csv')
counties_census_data.head(5)
# Out:
#        FIPS             Qualifying Name File identification  \
# 0  Geo_FIPS                   Geo_QName          Geo_FILEID
# 1     06001  Alameda County, California               ACSSF
# 2     06003   Alpine County, California               ACSSF
# 3     06005   Amador County, California               ACSSF
# 4     06007    Butte County, California               ACSSF
#
#   State Postal Abbreviation Summary Level Geographic Component  \
# 0                Geo_STUSAB    Geo_SUMLEV          Geo_GEOCOMP
# 1                        ca           050                   00
# 2                        ca           050                   00
# 3                        ca           050                   00
# 4                        ca           050                   00
#
#   Logical Record Number      US Census Region Census Division  ...  \
# 0          Geo_LOGRECNO  Geo_US    Geo_REGION    Geo_DIVISION  ...
# 1               0000013                                        ...
# ...

# %%
'california_counties.gpkg'

# %%
#Dropping first row with column descriptors
counties_census_data=counties_census_data.drop([0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 #Dropping first row with column descriptors
# ----> 2 counties_census_data=counties_census_data.drop([0])
#       3 counties_census_data
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
# ...

# %%
counties_gpkg = gpd.read_file(path2 + "/california_counties.gpkg")
counties_gpkg.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID           NAME              NAMELSAD LSAD  \
# 0      06      091  00277310  06091         Sierra         Sierra County   06
# 1      06      067  00277298  06067     Sacramento     Sacramento County   06
# 2      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
# 3      06      009  01675885  06009      Calaveras      Calaveras County   06
# 4      06      111  00277320  06111        Ventura        Ventura County   06
#
#   CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND      AWATER  \
# 0      H1  G4020   NaN    NaN      NaN        A  2468694587    23299110
# 1      H1  G4020   472  40900      NaN        A  2499183617    76073827
# 2      H1  G4020   NaN  42200      NaN        A  7084000598  2729814515
# 3      H1  G4020   NaN    NaN      NaN        A  2641820834    43806026
# 4      H1  G4020   348  37100      NaN        A  4773390489   945942791
#
#       INTPTLAT      INTPTLON  \
# 0  +39.5769252  -120.5219926
# ...

# %%
#Grouping each county with pop
counties_census_data.loc[:,["Qualifying Name", "Total Population"]]
# Out:
#                        Qualifying Name Total Population
# 1           Alameda County, California          1673133
# 2            Alpine County, California             1344
# 3            Amador County, California            40095
# 4             Butte County, California           217884
# 5         Calaveras County, California            45349
# 6            Colusa County, California            21780
# 7      Contra Costa County, California          1161643
# 8         Del Norte County, California            27655
# 9         El Dorado County, California           190568
# 10           Fresno County, California          1003150
# 11            Glenn County, California            28675
# 12         Humboldt County, California           137014
# 13         Imperial County, California           180051
# 14             Inyo County, California            18804
# 15             Kern County, California           905644
# 16            Kings County, California           151887
# ...

# %%
#Grouping each county with pop
cleaned_tract.loc[:,["county",'total_pop']]
# Out:
#      county total_pop
# 0       001      3324
# 1       001      2038
# 2       001      5449
# 3       001      4384
# 4       001      4048
# ...     ...       ...
# 9124    115      1730
# 9125    115      3910
# 9126    115      3408
# 9127    115      2620
# 9128    115       890
#
# [9129 rows x 2 columns]

# %%
#cleaned_tract.groupby("county").sum()[["total_pop"]].reset_index()
cleaned_tract.groupby('county').sum()[["tract"]].reset_index()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File /opt/tljh/user/lib/python3.9/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
capitals = gpd.read_file(data_path +
                         gpd.plot()

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=[1, 2, 3], y=[4, 5, 6]))
fig.show()

# %%
pd.merge()

# %%
capitals.plot(,color="yellow")

f, ax = plt.subplot(1, fugszze(2, 8))
title.plot('', ax=ax1) scheme = 'quantile', cmap="BuPu'
contextly.add_basemap(
    ax1, title)
