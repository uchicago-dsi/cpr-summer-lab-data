# %%
import pandas as pd
import geopandas as gpd
import os
import pyarrow
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
plt.style.use('fivethirtyeight')   
path = "/srv/data/my_shared_data_folder/cpr/"

# %%
pur2020_ag_data = pd.read_parquet("/srv/data/my_shared_data_folder/cpr/pur2020_ag.parquet", engine="fastparquet")
#ac_pur2020_ag_data = pd.read_parquet("/srv/data/my_shared_data_folder/cpr/another_copy_pur2020_ag.parquet", engine="fastparquet")

# %%
pur2020_ag_data = pur2020_ag_data.sample(frac = 0.001)
#list(pur2020_ag_data.columns)
pur2020_ag_data
# Out:
#           use_no  prodno  chem_code  prodchem_pct  lbs_chm_used  lbs_prd_used  \
# 2812526  1293670   56834        NaN           NaN           NaN       11.4600
# 4640198  1269308   63468        NaN           NaN           NaN        0.2681
# 2572529  1145943   56463     2008.0        25.000      0.562500        2.2500
# 3975021  2556912   73285     6109.0        21.800      0.499394        2.2908
# 2233560    97972   66040        NaN           NaN           NaN       24.3782
# ...          ...     ...        ...           ...           ...           ...
# 2350921  3652373   27453     2210.0        80.000      1.142880        1.4286
# 2063115  2116574   30319      216.0        30.500     79.523626      260.7332
# 6381756  4093243   56369     2308.0        24.000      1.519392        6.3308
# 6017717  1972216   63422     5935.0         0.063      0.141038      223.8700
# 4018874   109479   64132     6020.0        20.400      0.520424        2.5511
#
#          amt_prd_used unit_of_meas  acre_planted unit_planted  ...      MTR  \
# 2812526          1.25           GA         20.00            A  ...  M06S13E
# 4640198          4.00           OZ          3.00            A  ...  M07N05W
# 2572529          2.25           LB         11.90            A  ...  M12S04E
# 3975021          0.25           GA        131.00            A  ...  M14S02E
# 2233560          2.40           GA         80.00            A  ...  M12S19E
# ...               ...          ...           ...          ...  ...      ...
# 2350921        648.00           GR          4.50            A  ...  S10N34W
# 2063115         29.81           GA        159.00            A  ...  M22S22E
# 6381756          0.38           GA         45.00            A  ...  M18S26E
# 6017717        223.87           LB        149.25            A  ...  M15S13E
# 4018874         40.00           OZ         14.00            A  ...  M14S03E
#
#              CO_MTRS  REGION     CO_MTR  County_CDn              NAMELSAD  \
# 2812526  24M06S13E23     5.0  24M06S13E        24.0         Merced County
# 4640198  28M07N05W13     2.0  28M07N05W        28.0           Napa County
# 2572529  35M12S04E20     3.0  35M12S04E        35.0     San Benito County
# 3975021  27M14S02E24     3.0  27M14S02E        27.0       Monterey County
# 2233560  20M12S19E02     5.0  20M12S19E        20.0         Madera County
# ...              ...     ...        ...         ...                   ...
# 2350921  42S10N34W08     3.0  42S10N34W        42.0  Santa Barbara County
# 2063115  16M22S22E09     5.0  16M22S22E        16.0          Kings County
# 6381756  54M18S26E09     5.0  54M18S26E        54.0         Tulare County
# 6017717  10M15S13E11     5.0  10M15S13E        10.0         Fresno County
# 4018874  27M14S03E11     3.0  27M14S03E        27.0       Monterey County
#
#                                                   geometry  \
# 2812526  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 4640198  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x06\x00...
# 2572529  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x0e\x00...
# 3975021  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x06\x00...
# 2233560  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# ...                                                    ...
# 2350921  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x05\x00...
# 2063115  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x06\x00...
# 6381756  b"\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...
# 6017717  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x06\x00...
# 4018874  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x06\x00...
#
#                             site_name COUNTYFP    county_name
# 2812526                        ALMOND       47         Merced
# 4640198                   GRAPE, WINE       55           Napa
# 2572529                 LETTUCE, LEAF       69     San Benito
# 3975021                 LETTUCE, LEAF       53       Monterey
# 2233560                     PISTACHIO       39         Madera
# ...                               ...      ...            ...
# 2350921           N-OUTDR TRANSPLANTS       83  Santa Barbara
# 2063115                       ALFALFA       31          Kings
# 6381756  N-OUTDR PLANTS IN CONTAINERS      107         Tulare
# 6017717                        ALMOND       19         Fresno
# 4018874                          KALE       53       Monterey
#
# [7464 rows x 55 columns]

# %%
pur2020_ag_data['prodno'].apply(str)
distinct_pesticides = pur2020_ag_data.prodno.unique()
len(distinct_pesticides)
# Out:
# 1175

# %%
#pest_type = pur2020_ag_data.groupby("prodno")["lbs_prd_used"].sum()
pest_type = pest_type.reset_index().rename(columns={'lbs_prd_used':'total_amt_used_(lbs)'})
pest_type
# Out:
#       level_0  index  prodno  total_amt_used_(lbs)
# 0           0      0     268                0.9913
# 1           1      1     270               17.1839
# 2           2      2     340                4.5815
# 3           3      3     373                4.0000
# 4           4      4    1774               60.0000
# ...       ...    ...     ...                   ...
# 1218     1218   1218   73379              415.8533
# 1219     1219   1219   73445                7.5000
# 1220     1220   1220   73535                2.9866
# 1221     1221   1221   73547               74.3240
# 1222     1222   1222   73598              161.7000
#
# [1223 rows x 4 columns]

# %%
pest_use_county = pur2020_ag_data.groupby("county_name")["prodno"].count()
pest_use_county = pest_use_county.reset_index()
pest_use_county

plt.figure(figsize=(7,11)) 
plt.barh(y = pest_use_county['county_name'], width= pest_use_county['prodno'])
plt.xticks(rotation=270)                           # Rotate x-labels by 270 degrees
plt.xlabel('Number of Pesticides')                      # x-label added
plt.ylabel('County Name')          # y-label added
plt.title('Number of Pesticides Used by County')  # title added
plt.show()

# %%
pest_amt_county = pur2020_ag_data.groupby("county_name")["lbs_prd_used"].sum()
pest_amt_county = pest_amt_county.reset_index()
pest_amt_county

plt.figure(figsize=(7,11)) 
plt.barh(y = pest_amt_county['county_name'], width = pest_amt_county['lbs_prd_used'])
plt.xticks(rotation=270)                           # Rotate x-labels by 270 degrees
plt.xlabel('Amount of Pesticide (lbs)')                      # x-label added
plt.ylabel('County Name')          # y-label added
plt.title('Amount of Pesticide Used by County')  # title added
plt.show()

# %%
#acre_treated_county = pur2020_ag_data.groupby("county_name")["acre_treated"].sum()
#acre_treated_county = acre_treated_county.reset_index()
acre_treated_county

plt.figure(figsize=(7,11)) 
plt.barh(y = acre_treated_county['county_name'], width= acre_treated_county['acre_treated'])
plt.xticks(rotation=270)                           # Rotate x-labels by 270 degrees
plt.xlabel('Total Acres Treated')                      # x-label added
plt.ylabel('County Name')          # y-label added
plt.title('Total Acres Treated by County')  # title added
plt.show()

# %%
cali_counties = gpd.read_file(path + "california_counties.gpkg")
cali_counties['county'] = cali_counties['NAMELSAD'].str.split(' ', expand=True)[0]
cali_counties.head(2)
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID        NAME           NAMELSAD LSAD  \
# 0      06      091  00277310  06091      Sierra      Sierra County   06
# 1      06      067  00277298  06067  Sacramento  Sacramento County   06
#
#   CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER  \
# 0      H1  G4020   NaN    NaN      NaN        A  2468694587  23299110
# 1      H1  G4020   472  40900      NaN        A  2499183617  76073827
#
#       INTPTLAT      INTPTLON  \
# 0  +39.5769252  -120.5219926
# 1  +38.4500114  -121.3404409
#
#                                             geometry      county
# 0  MULTIPOLYGON (((-13431319.751 4821511.426, -13...      Sierra
# 1  MULTIPOLYGON (((-13490651.476 4680831.603, -13...  Sacramento

# %%
cali_county_cleaned = pd.read_csv(path + "cleaned_county_data.csv")
cali_county_cleaned['county'] = cali_county_cleaned['area_name'].str.split(' ', expand=True)[0]
cali_county_cleaned.head(2)
# Out:
#    FIPS state  state_fips   county  tract         geoid       area_name  \
# 0  6001    ca           6  Alameda    NaN  05000US06001  Alameda County
# 1  6003    ca           6   Alpine    NaN  05000US06003   Alpine County
#
#     area_land  total_pop  housing_units  ...  \
# 0  737.461875    1673133         617045  ...
# 1  738.340335       1344           1626  ...
#
#    pct_families_income_below_poverty_level  \
# 0                                 0.055331
# 1                                 0.062937
#
#    pct_households_receiving_assistance  pct_nh_white_alone  \
# 0                             0.589847            0.298679
# 1                             0.665899            0.543155
#
#    pct_nh_black_or_african_american_alone  \
# 0                                0.099225
# 1                                0.005952
#
#    pct_nh_american_indian_and_alaska_native_alone  pct_nh_asian_alone  \
# 0                                        0.003137            0.313771
# 1                                        0.263393            0.007440
#
#    pct_nh_native_hawaiian_and_other_pacific_islander_alone  pct_nh_other  \
# 0                                            0.00759            0.005165
# 1                                            0.00000            0.000000
#
#    pct_nh_two_or_more  pct_hispanic_or_latino
# 0            0.048577                0.223857
# 1            0.033482                0.146577
#
# [2 rows x 37 columns]

# %%
# Finding Common columns
a = np.intersect1d(cali_counties.columns, cali_county_cleaned.columns)
 
# Printing common columns
print ("Common Columns:",a)
# Out:
# Common Columns: ['county']

# %%
cali_counties_merged =  pd.merge(cali_counties, cali_county_cleaned, on='county')
cali_counties_merged.head(5)
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID           NAME              NAMELSAD LSAD  \
# 0      06      091  00277310  06091         Sierra         Sierra County   06
# 1      06      067  00277298  06067     Sacramento     Sacramento County   06
# 2      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
# 3      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
# 4      06      083  00277306  06083  Santa Barbara  Santa Barbara County   06
#
#   CLASSFP  MTFCC CSAFP  ... pct_families_income_below_poverty_level  \
# 0      H1  G4020   NaN  ...                                0.031593
# 1      H1  G4020   472  ...                                0.095517
# 2      H1  G4020   NaN  ...                                0.074455
# 3      H1  G4020   NaN  ...                                0.040322
# 4      H1  G4020   NaN  ...                                0.058754
#
#   pct_households_receiving_assistance pct_nh_white_alone  \
# 0                            0.412685           0.874310
# 1                            0.665029           0.428914
# 2                            0.678160           0.430253
# 3                            0.651457           0.298595
# 4                            0.535822           0.561373
#
#    pct_nh_black_or_african_american_alone  \
# 0                                0.000650
# 1                                0.092836
# 2                                0.017536
# 3                                0.023266
# 4                                0.008338
#
#    pct_nh_american_indian_and_alaska_native_alone pct_nh_asian_alone  \
# 0                                        0.009094           0.000000
# 1                                        0.002581           0.166184
# 2                                        0.003436           0.052968
# 3                                        0.001582           0.379351
# 4                                        0.000768           0.047340
#
#   pct_nh_native_hawaiian_and_other_pacific_islander_alone pct_nh_other  \
# 0                                           0.000000          0.000000
# 1                                           0.011062          0.003770
# 2                                           0.000929          0.003119
# 3                                           0.003124          0.003639
# 4                                           0.001227          0.004163
#
#   pct_nh_two_or_more  pct_hispanic_or_latino
# 0           0.003897                0.112049
# 1           0.056239                0.238414
# 2           0.028109                0.463651
# 3           0.039363                0.251080
# 4           0.036371                0.340419
#
# [5 rows x 55 columns]
