# %%
import pandas as pd
import geopandas as gpd
import os
import pyarrow

# %%
pur2020_ag_data = pd.read_parquet("/srv/data/my_shared_data_folder/cpr/pur2020_ag.parquet", engine="fastparquet")
pur2020_ag_data.head(2)
# Out:
#    use_no  prodno  chem_code  prodchem_pct  lbs_chm_used  lbs_prd_used  \
# 0  956467   71697      560.0          80.0         6.216          7.77
# 1  956473   71697      560.0          80.0        10.680         13.35
#
#    amt_prd_used unit_of_meas  acre_planted unit_planted  ...      MTR  \
# 0          7.77           LB        169.53            A  ...  M09N08W
# 1         13.35           LB        169.53            A  ...  M09N08W
#
#        CO_MTRS  REGION     CO_MTR  County_CDn       NAMELSAD  \
# 0  49M09N08W06     1.0  49M09N08W        49.0  Sonoma County
# 1  49M09N08W06     1.0  49M09N08W        49.0  Sonoma County
#
#                                             geometry    site_name COUNTYFP  \
# 0  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...  GRAPE, WINE       97
# 1  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x07\x00...  GRAPE, WINE       97
#
#    county_name
# 0       Sonoma
# 1       Sonoma
#
# [2 rows x 55 columns]

# %%
pur2020_ag_data = pur2020_ag_data.sample(frac = 0.01)
pur2020_ag_data
# Out:
#           use_no  prodno  chem_code  prodchem_pct  lbs_chm_used  lbs_prd_used  \
# 2255135   971142   57594      560.0          80.0    192.000000      240.0000
# 3907634   235437   50828        NaN           NaN           NaN       20.3460
# 4118944   962426   45490        NaN           NaN           NaN        6.9272
# 1866558  2821334   71330        NaN           NaN           NaN       37.3601
# 5508578   183308   51252     1929.0          38.7    145.832591      376.8284
# ...          ...     ...        ...           ...           ...           ...
# 6989020  3648752   62002     4020.0           5.0      0.159000        3.1800
# 4270826   822414   27734        NaN           NaN           NaN        2.6531
# 1989185  3710131   60986     5977.0          70.0      0.392000        0.5600
# 6711324   440330   33638     2234.0          30.9      0.293241        0.9490
# 168875    914268   53989     2297.0          12.7      0.399047        3.1421
#
# ...

# %%
pur2020_ag_data.groupby("county_name")["use_no"].count()
# Out:
# county_name
# Alameda              146
# Amador                92
# Butte               1103
# Calaveras             37
# Colusa              1037
# Contra Costa         262
# Del Norte             68
# El Dorado            139
# Fresno              7710
# Glenn                974
# Humboldt              85
# Imperial            2003
# Inyo                   2
# Kern                4408
# Kings               1836
# Lake                 190
# Lassen                27
# Los Angeles          224
# Madera              2121
# Marin                  9
# Mariposa              10
# Mendocino            229
# Merced              2561
# Modoc                 86
# Mono                   6
# Monterey           12117
# Napa                1628
# Nevada                17
# Orange                68
# Placer               101
# Plumas                 3
# Riverside           1966
# Sacramento           764
# San Benito          1162
# San Bernardino       152
# San Diego           1969
# ...

# %%
cali_school_dist = gpd.read_file("/srv/data/my_shared_data_folder/cpr/california_elementary_school_districts.gpkg") 
cali_school_dist
