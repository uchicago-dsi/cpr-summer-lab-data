# %%
import os
import pandas as pd
import geopandas as gpd
import json
import matplotlib.pyplot as plt
import fiona
import contextily
pd.set_option('display.max_columns', None)

path = "/srv/data/my_shared_data_folder/cpr/"

#dir_list = os.listdir(path)
#print(dir_list)

# %%
Fresno = pd.read_parquet('./Fresno_pd.parquet', engine = 'fastparquet')
Fresno_geo = gpd.read_parquet("./Fresno_geo.parquet")

# %%
Fresno.head(4)
# Out:
#          identifier   use_no  prodno  chem_code  prodchem_pct  lbs_chm_used  \
# 3046062     3046185  1237468   50717        NaN           NaN           NaN
# 3046063     3046186  1115553   27734        NaN           NaN           NaN
# 3046064     3046187  1116398   65921     2254.0           2.0      0.979708
# 3046065     3046188  1116449   66171     2297.0          22.8     10.066268
#
#          lbs_prd_used  amt_prd_used unit_of_meas  acre_planted unit_planted  \
# 3046062        0.1666          0.02           GA          15.0            A
# 3046063       14.2510          1.88           GA          25.0            A
# 3046064       48.9854          5.94           GA          38.0            A
# 3046065       44.1503          4.80           GA         240.0            A
#
#          acre_treated unit_treated  applic_cnt   applic_dt  applic_time  \
# 3046062          15.0            A         1.0  05/04/2020       1000.0
# ...

# %%
Fresno_geo.head(4)
# Out:
#          identifier                                           geometry  \
# 3046062     3046185  POLYGON ((-120.47280 36.92327, -120.46069 36.9...
# 3046063     3046186  POLYGON ((-119.86304 36.66349, -119.86256 36.6...
# 3046064     3046187  POLYGON ((-119.82672 36.70681, -119.80905 36.7...
# 3046065     3046188  POLYGON ((-120.63950 36.69214, -120.63974 36.6...
#
#         county_name
# 3046062      Fresno
# 3046063      Fresno
# 3046064      Fresno
# 3046065      Fresno

# %%
Fresno_geo.drop(labels = ['county_name'],axis = 1,inplace = True)

# %%
Fresno.drop(labels = ['geometry'], axis = 1 ,inplace = True)

# %%
Fresno
# Out:
#          identifier   use_no  prodno  chem_code  prodchem_pct  lbs_chm_used  \
# 3046062     3046185  1237468   50717        NaN           NaN           NaN
# 3046063     3046186  1115553   27734        NaN           NaN           NaN
# 3046064     3046187  1116398   65921     2254.0          2.00      0.979708
# 3046065     3046188  1116449   66171     2297.0         22.80     10.066268
# 3046066     3046189  1118214   39374     3983.0         22.80      2.089164
# ...             ...      ...     ...        ...           ...           ...
# 6288545     6288717  2760103   58878     5792.0         23.00     11.378606
# 6288546     6288718  3136337   62970     5321.0         21.40      7.308571
# 6288547     6288719  2989348   51917     2251.0         88.54      0.510256
# 6288548     6288720  3134672   57011     5820.0         48.70     44.133742
# 6288549     6288721  3134685   57594      560.0         80.00     96.000000
#
# ...

# %%
Fresno_geoC = Fresno_geo

# %%
Fresno_geoC
# Out:
#          identifier                                           geometry
# 3046062     3046185  POLYGON ((-120.47280 36.92327, -120.46069 36.9...
# 3046063     3046186  POLYGON ((-119.86304 36.66349, -119.86256 36.6...
# 3046064     3046187  POLYGON ((-119.82672 36.70681, -119.80905 36.7...
# 3046065     3046188  POLYGON ((-120.63950 36.69214, -120.63974 36.6...
# 3046066     3046189  POLYGON ((-119.39454 36.71975, -119.39483 36.7...
# ...             ...                                                ...
# 6288545     6288717  POLYGON ((-120.00633 36.69169, -120.00102 36.6...
# 6288546     6288718  POLYGON ((-119.60998 36.80854, -119.61002 36.7...
# 6288547     6288719  POLYGON ((-119.53890 36.53249, -119.52089 36.5...
# 6288548     6288720  POLYGON ((-120.13343 36.61855, -120.11524 36.6...
# 6288549     6288721  POLYGON ((-119.68224 36.66371, -119.68080 36.6...
#
# [777048 rows x 2 columns]

# %%
Fresno_geoC = Fresno_geoC.merge(Fresno, on = 'identifier')

# %%
Fresno_geoC
# Out:
#         identifier                                           geometry  \
# 0          3046185  POLYGON ((-120.47280 36.92327, -120.46069 36.9...
# 1          3046186  POLYGON ((-119.86304 36.66349, -119.86256 36.6...
# 2          3046187  POLYGON ((-119.82672 36.70681, -119.80905 36.7...
# 3          3046188  POLYGON ((-120.63950 36.69214, -120.63974 36.6...
# 4          3046189  POLYGON ((-119.39454 36.71975, -119.39483 36.7...
# ...            ...                                                ...
# 777043     6288717  POLYGON ((-120.00633 36.69169, -120.00102 36.6...
# 777044     6288718  POLYGON ((-119.60998 36.80854, -119.61002 36.7...
# 777045     6288719  POLYGON ((-119.53890 36.53249, -119.52089 36.5...
# 777046     6288720  POLYGON ((-120.13343 36.61855, -120.11524 36.6...
# 777047     6288721  POLYGON ((-119.68224 36.66371, -119.68080 36.6...
#
#          use_no  prodno  chem_code  prodchem_pct  lbs_chm_used  lbs_prd_used  \
# ...

# %%
Fresno_geoC.to_parquet('Fresno_complete.parquet')
